# %% [markdown]
# ![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)
#
# <a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/testing/test.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>

# %% [markdown]
# # Adding "Open In Callysto" Buttons to notebooks

# %%
import os
import json
import pandas as pd

def button_code_generator(notebook_path, notebook_filename):
    notebook_path = notebook_path.replace('./','',1)
    button_image = 'https://raw.githubusercontent.com/callysto/curriculum-notebooks/master/open-in-callysto-button.svg?sanitize=true'
    repo_path = 'https%3A%2F%2Fgithub.com%2Fcallysto%2Fcurriculum-notebooks&branch=master'
    a = '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo='
    size_etc = '" width="123" height="24" alt="Open in Callysto"/></a>'
    button_code = a+repo_path+'&subPath='+notebook_path+'/'+notebook_filename+'&depth=1" target="_parent"><img src="'+button_image+size_etc
    return button_code

def replace_first_cell(notebook_name_and_path, first_cell_code):
    original_file = open(notebook_name_and_path, 'r')
    notebook_contents = json.load(original_file)
    original_file.close()
    del notebook_contents['cells'][0]
    notebook_contents['cells'].insert(0, first_cell_code)
    with open(notebook_name_and_path, 'w') as notebook_file:
        json.dump(notebook_contents, notebook_file)

# %% [markdown]
# ## Create Notebooks DataFrame

# %%
df = pd.DataFrame(columns=['Notebook', 'Button Code'])
for root, dirs, files in os.walk("."):
    for filename in files:
        if filename.endswith('.ipynb'):
            if not 'checkpoint' in filename:
                notebook_name_and_path = os.path.join(root, filename).strip('./')

                button_code = button_code_generator(root, filename)
                df = df.append({'Notebook':notebook_name_and_path, 'Button Code':button_code}, ignore_index=True)
df
# Out:
#                                              Notebook  \
# 0                    ./notebooks-button-creator.ipynb
# 1                                   ./commencer.ipynb
# 2           ./EtudesSociales/la-times-extension.ipynb
# 3   ./EtudesSociales/PIBProvincialParIndustrie/pib...
# 4        ./Technologie/OpenDataExamples/loterie.ipynb
# 5   ./Technologie/OpenDataExamples/kilométrage-de-...
# 6   ./Technologie/OpenDataExamples/kilométrage-de-...
# 7   ./Technologie/OpenDataExamples/météorites-1.ipynb
# 8   ./Technologie/OpenDataExamples/introduction-au...
# 9   ./Technologie/OpenDataExamples/météorites-2.ipynb
# 10  ./Technologie/JournalNumérique/journal-numériq...
# 11  ./Science/DésintégrationRadioactive/désintégra...
# 12  ./Science/ChangementClimatique/changement-clim...
# 13  ./Science/ConductivitéÉlectrique/conductivit...
# 14  ./Science/ModèleDeRapportDeLaboratoire/modèle-...
# 15  ./Science/ModèleDeRapportDeLaboratoire/modèle-...
# 16                            ./Tutoriels/LaTeX.ipynb
# 17                         ./Tutoriels/markdown.ipynb
# 18                           ./Tutoriels/Python.ipynb
# 19  ./Mathématiques/introduction-aux-fonctions-ma...
# 20     ./Mathématiques/Réflexions/réflexions.ipynb
#
#                                           Button Code
# 0   <a href="https://hub.callysto.ca/jupyter/hub/u...
# 1   <a href="https://hub.callysto.ca/jupyter/hub/u...
# 2   <a href="https://hub.callysto.ca/jupyter/hub/u...
# 3   <a href="https://hub.callysto.ca/jupyter/hub/u...
# 4   <a href="https://hub.callysto.ca/jupyter/hub/u...
# 5   <a href="https://hub.callysto.ca/jupyter/hub/u...
# 6   <a href="https://hub.callysto.ca/jupyter/hub/u...
# 7   <a href="https://hub.callysto.ca/jupyter/hub/u...
# 8   <a href="https://hub.callysto.ca/jupyter/hub/u...
# 9   <a href="https://hub.callysto.ca/jupyter/hub/u...
# 10  <a href="https://hub.callysto.ca/jupyter/hub/u...
# 11  <a href="https://hub.callysto.ca/jupyter/hub/u...
# 12  <a href="https://hub.callysto.ca/jupyter/hub/u...
# 13  <a href="https://hub.callysto.ca/jupyter/hub/u...
# 14  <a href="https://hub.callysto.ca/jupyter/hub/u...
# 15  <a href="https://hub.callysto.ca/jupyter/hub/u...
# 16  <a href="https://hub.callysto.ca/jupyter/hub/u...
# 17  <a href="https://hub.callysto.ca/jupyter/hub/u...
# 18  <a href="https://hub.callysto.ca/jupyter/hub/u...
# 19  <a href="https://hub.callysto.ca/jupyter/hub/u...
# 20  <a href="https://hub.callysto.ca/jupyter/hub/u...

# %% [markdown]
# ## Iterate through the DataFrame
#
# Replace the first cell in each notebook with the banner and button.

# %%
for i, row in df.iterrows():
    notebook_name_and_path = row['Notebook']
    banner_code = '![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)'
    first_cell_code = {'cell_type': 'markdown', 'metadata': {}, 'source': [banner_code, '\n', '\n', row['Button Code']]}
    if notebook_name_and_path != './notebooks-button-creator.ipynb':
        replace_first_cell(notebook_name_and_path, first_cell_code)

# %% [markdown]
# ## Check our Work

# %%
df2 = pd.DataFrame(columns=['Name','First Cell'])
for root, dirs, files in os.walk("."):
    for filename in files:
        if filename.endswith('.ipynb'):
            if not 'checkpoint' in filename:
                notebook_name = filename[:-6]
                notebook_name_and_path = os.path.join(root, filename)
                notebook = json.load(open(notebook_name_and_path))
                first_cell = notebook['cells'][0]['source']#[0]
                #last_cell = notebook['cells'][-1]['source']#[0]
                button_code = button_code_generator(root, filename)
                df2 = df2.append({'Name':notebook_name,'First Cell':first_cell}, ignore_index=True)
for i, row in df2.iterrows():
    print(i, row['Name'])
    print(row['First Cell'])
    print('')
# Out:
# 0 notebooks-button-creator
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/testing/test.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 1 commencer
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/commencer.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 2 la-times-extension
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/EtudesSociales/la-times-extension.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 3 pib-provincial-par-industrie
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/EtudesSociales/PIBProvincialParIndustrie/pib-provincial-par-industrie.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 4 loterie
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/Technologie/OpenDataExamples/loterie.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 5 kilométrage-de-voiture-1
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/Technologie/OpenDataExamples/kilométrage-de-voiture-1.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 6 kilométrage-de-voiture-2
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/Technologie/OpenDataExamples/kilométrage-de-voiture-2.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 7 météorites-1
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/Technologie/OpenDataExamples/météorites-1.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 8 introduction-aux-données-ouvertes
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/Technologie/OpenDataExamples/introduction-aux-données-ouvertes.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 9 météorites-2
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/Technologie/OpenDataExamples/météorites-2.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 10 journal-numérique-du-camp-d'été
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/Technologie/JournalNumérique/journal-numérique-du-camp-d\'été.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 11 désintégration-radioactive
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/Science/DésintégrationRadioactive/désintégration-radioactive.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 12 changement-climatique
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/Science/ChangementClimatique/changement-climatique.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 13 conductivité-électrique
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/Science/ConductivitéÉlectrique/conductivité-électrique.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 14 modèle-de-rapport-de-laboratoire-tutoriel
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/Science/ModèleDeRapportDeLaboratoire/modèle-de-rapport-de-laboratoire-tutoriel.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 15 modèle-de-rapport-de-laboratoire
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/Science/ModèleDeRapportDeLaboratoire/modèle-de-rapport-de-laboratoire.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 16 LaTeX
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/Tutoriels/LaTeX.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 17 markdown
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/Tutoriels/markdown.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 18 Python
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/Tutoriels/Python.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 19 introduction-aux-fonctions-mathématiques
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/Mathématiques/introduction-aux-fonctions-mathématiques.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']
#
# 20 réflexions
# ['![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)', '\n', '\n', '<a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcahiers-de-programmes&branch=master&subPath=/Mathématiques/Réflexions/réflexions.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/cahiers-de-programmes/master/bouton-callysto.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>']

# %% [markdown]
# [![Callysto.ca License](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-bottom.jpg?raw=true)](https://github.com/callysto/curriculum-notebooks/blob/master/LICENSE.md)
