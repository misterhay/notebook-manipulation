# %% [markdown]
# # Pull Info From Google Slides
#
# https://developers.google.com/slides/quickstart/python

# %%
presentation_id = '1lh-V3JuuoELM2j_54mksfD_8ta8aPMBuWQ0EyFlp6wI'
client_id = '973968926785-jh79shf4dto2j9dou2chuai99q9mult8.apps.googleusercontent.com'
client_secret = 'e-FIPfOpQc2ej86HvH6eDggt'

# %% [markdown]
# # Heading 1
#
# ## Heading 2
#
# **bold**  *italics*
#
# [Watch the solution video](https://google.ca)
#
# `This is formatted as code`

# %%
#!pip install --user google-api-python-client google-auth-httplib2 google-auth-oauthlib
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

# If modifying these scopes, delete the file token.pickle.
SCOPES = ['https://www.googleapis.com/auth/presentations.readonly']
#os.remove('token.pickle')

# The ID of a sample presentation.
PRESENTATION_ID = '1lh-V3JuuoELM2j_54mksfD_8ta8aPMBuWQ0EyFlp6wI' #'1EAYk18WDjIG-zp_0vLm3CsfQh_i8eXc67Jo2O9C6Vuc'

creds = None
if os.path.exists('token.pickle'):
    with open('token.pickle', 'rb') as token:
        creds = pickle.load(token)
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file('credentials.json', SCOPES)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('token.pickle', 'wb') as token:
        pickle.dump(creds, token)

service = build('slides', 'v1', credentials=creds)

# Call the Slides API
presentation = service.presentations().get(presentationId=PRESENTATION_ID).execute()
slides = presentation.get('slides')

#print('The presentation contains {} slides:'.format(len(slides)))
for i, slide in enumerate(slides):
    print(slide)
    print('')
#for i, slide in enumerate(slides):
#    print('- Slide #{} contains {} elements.'.format(i + 1, len(slide.get('pageElements'))))
# Out:
# {'objectId': 'g6da56460fa_0_5', 'pageElements': [{'objectId': 'g6da56460fa_0_6', 'size': {'width': {'magnitude': 3000000, 'unit': 'EMU'}, 'height': {'magnitude': 3000000, 'unit': 'EMU'}}, 'transform': {'scaleX': 2.8402, 'scaleY': 0.6842, 'translateX': 311708.35000000003, 'translateY': 744575, 'unit': 'EMU'}, 'shape': {'shapeType': 'TEXT_BOX', 'text': {'textElements': [{'endIndex': 22, 'paragraphMarker': {'style': {'direction': 'LEFT_TO_RIGHT'}}}, {'endIndex': 22, 'textRun': {'content': 'Teaching Data Science\n', 'style': {'bold': False, 'fontFamily': 'Comic Sans MS', 'weightedFontFamily': {'fontFamily': 'Comic Sans MS', 'weight': 400}}}}, {'startIndex': 22, 'endIndex': 36, 'paragraphMarker': {'style': {'direction': 'LEFT_TO_RIGHT'}}}, {'startIndex': 22, 'endIndex': 36, 'textRun': {'content': 'In Elementary\n', 'style': {'bold': False, 'fontFamily': 'Comic Sans MS', 'weightedFontFamily': {'fontFamily': 'Comic Sans MS', 'weight': 400}}}}]}, 'shapeProperties': {'shapeBackgroundFill': {'
# ...

# %%
import pprint
pprint.pprint(slides[0])#['pageElements'])
# Out:
# {'objectId': 'g6da56460fa_0_5',
#  'pageElements': [{'objectId': 'g6da56460fa_0_6',
#                    'shape': {'placeholder': {'parentObjectId': 'p2_i0',
#                                              'type': 'CENTERED_TITLE'},
#                              'shapeProperties': {'outline': {'propertyState': 'INHERIT'},
#                                                  'shadow': {'propertyState': 'INHERIT'},
#                                                  'shapeBackgroundFill': {'propertyState': 'INHERIT'}},
#                              'shapeType': 'TEXT_BOX',
#                              'text': {'textElements': [{'endIndex': 22,
#                                                         'paragraphMarker': {'style': {'direction': 'LEFT_TO_RIGHT'}}},
#                                                        {'endIndex': 22,
#                                                         'textRun': {'content': 'Teaching '
# ...

# %%
thing = slides[0]['pageElements'][0]['shape']['text']['textElements'][1]['textRun']['content']
pprint.pprint(thing)
#print(len(thing))
#for itera, item in enumerate(thing):
#    print(itera, item)
# Out:
# {'textElements': [{'endIndex': 22,
#                    'paragraphMarker': {'style': {'direction': 'LEFT_TO_RIGHT'}}},
#                   {'endIndex': 22,
#                    'textRun': {'content': 'Teaching Data Science\n',
#                                'style': {'bold': False,
#                                          'fontFamily': 'Comic Sans MS',
#                                          'weightedFontFamily': {'fontFamily': 'Comic '
#                                                                               'Sans '
#                                                                               'MS',
#                                                                 'weight': 400}}}},
#                   {'endIndex': 36,
#                    'paragraphMarker': {'style': {'direction': 'LEFT_TO_RIGHT'}},
#                    'startIndex': 22},
#                   {'endIndex': 36,
#                    'startIndex': 22,
# ...

# %%
def find_text(page_element):
    for i in page_element['shape']:
        if i == 'text':
            #print(page_element['shape'][i]['textElements'])
            for j in page_element['shape'][i]['textElements']:
                print(j)
                try:
                    print(page_element['shape'][i]['textElements']['textRun']['content'])
                except:
                    pass
                #for k in page_element['shape'][i]['textElements']:
                #    print[k]
                print('')
            
            print('')
    #return boolean

#element = slides[0]['pageElements'][0]['shape']['text']['textElements'][1]['textRun']['content']
page_element = slides[0]['pageElements'][0]
for page_element in slides[0]['pageElements']:
    find_text(page_element)
# Out:
# {'endIndex': 22, 'paragraphMarker': {'style': {'direction': 'LEFT_TO_RIGHT'}}}
#
# {'endIndex': 22, 'textRun': {'content': 'Teaching Data Science\n', 'style': {'bold': False, 'fontFamily': 'Comic Sans MS', 'weightedFontFamily': {'fontFamily': 'Comic Sans MS', 'weight': 400}}}}
#
# {'startIndex': 22, 'endIndex': 36, 'paragraphMarker': {'style': {'direction': 'LEFT_TO_RIGHT'}}}
#
# {'startIndex': 22, 'endIndex': 36, 'textRun': {'content': 'In Elementary\n', 'style': {'bold': False, 'fontFamily': 'Comic Sans MS', 'weightedFontFamily': {'fontFamily': 'Comic Sans MS', 'weight': 400}}}}
#
#
# {'endIndex': 20, 'paragraphMarker': {'style': {'indentStart': {'unit': 'PT'}, 'indentFirstLine': {'unit': 'PT'}, 'direction': 'LEFT_TO_RIGHT'}}}
#
# {'endIndex': 20, 'textRun': {'content': 'David.Hay@cybera.ca\n', 'style': {'bold': False, 'fontFamily': 'Comic Sans MS', 'weightedFontFamily': {'fontFamily': 'Comic Sans MS', 'weight': 400}}}}
#
# ...

# %%
# slides[0]['pageElements'][0]['shape']['text']['textElements'][1]['textRun']['content']
for slide in slides:
    try:
        for element in slide['pageElements']:
            try:
                for thing in element['shape']['text']['textElements']:
                    try:
                        print(thing['textRun']['content'])
                    except:
                        pass
                    #print(thing)
                #pprint.pprint(element['shape']['text']['textElements'])
            except:
                pass
    except:
        pass
# Out:
# Teaching Data Science
#
# In Elementary
#
# David.Hay@cybera.ca
#
# @misterhay
#
#
#
# bit.ly/DataScienceElementary
#
# http://bit.ly/callysto-sign-in
#
# Teaching Data Science in Elementary
#
# The ability to process information in an analytical way is becoming increasingly important, and educators are encouraged or expected to incorporate more coding and data analytics into their teaching. Callysto is a free online platform designed for students in Grade 5 and up. It is capable of engaging data visualizations, big data processing, coding, and text formatting.
#
# Teachers will be introduced to the federally-funded Callysto platform, and will be able to explore Python-based modules developed for teaching outcomes in elementary science. We will talk about how to incorporate these into your classroom, and help you create or edit modules for other outcomes if you are interested.
#
# Who Is Here?
#
# What is Callysto?
#
# The Callysto Project
#
# Making open educational
# ...
